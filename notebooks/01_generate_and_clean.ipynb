# %% [markdown]
# # 01 — Generate & Clean Synthetic Campaign Data
#
# This repo includes the generated CSVs already.
# If you want to regenerate the dataset, use this notebook as your starting point.
#
# **Seed:** 753

# %%
import pandas as pd
from pathlib import Path

ROOT = Path('..').resolve()
fact = pd.read_csv(ROOT / 'data' / 'processed' / 'fact_channel_daily.csv')
fact.head()

# %% [markdown]
# ## Power BI tip
#
# Start in Power BI with `fact_channel_daily.csv`.
# Then bring in `brand_interest_index.csv` and `gym_activity.csv` for the story.
